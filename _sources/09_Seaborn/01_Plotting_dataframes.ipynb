# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_csv = pd.read_csv(r'../../data/3D/table_nuclei.csv')
df_csv
# Out:
#     Unnamed: 0  label   area  bbox_area  convex_area  equivalent_diameter  \
# 0            0      2  54018      95160        56545            46.900769
# 1            1      5  33789      71400        37316            40.110577
# 2            2      6  37770      84150        40336            41.627736
# 3            3     10  62690     138355        70018            49.287094
# 4            4     12  35227      67840        37057            40.671702
# 5            5     13  50281      96720        53668            45.793281
# 6            6     14  47652      91035        49683            44.980834
# 7            7     15  39960      74307        42190            42.417228
# 8            8     18  41456      78336        43518            42.940087
# 9            9     20  37480      77175        39760            41.520922
# 10          10     21  53894     119662        61516            46.864854
#
#     max_intensity  mean_intensity  min_intensity  solidity    extent  \
# ...
