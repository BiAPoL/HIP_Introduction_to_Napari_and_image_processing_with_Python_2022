# %% [markdown]
# # Introduction to Seaborn

# %% [markdown]
# The definition of seaborn's website is so concise that we replicate it here:
#
# "Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures."
#
# That's it! The main benefit of using it is that it is a more high-level library, which means we can achieve sophisticated plots with much less lines of code. Most axes style customization are done automatically. It can automatically provide plots with summary statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Plotting a graph with seaborn

# %% [markdown]
# Let's load the same dataframe.

# %%
df = pd.read_csv("../../data/BBBC007_analysis.csv")
df.head()
# Out:
#    Unnamed: 0  area  intensity_mean  major_axis_length  minor_axis_length  \
# 0           0   139       96.546763          17.504104          10.292770
# 1           1   360       86.613889          35.746808          14.983124
# 2           2    43       91.488372          12.967884           4.351573
# 3           3   140       73.742857          18.940508          10.314404
# 4           4   144       89.375000          13.639308          13.458532
#
#    aspect_ratio
# 0      1.700621
# 1      2.385805
# 2      2.980045
# 3      1.836316
# 4      1.013432

# %% [markdown]
# And make a scatter plot of aspect_ratio vs intensity mean.

# %%
sns.relplot(data=df, x="aspect_ratio", y="intensity_mean")

# %%
sns.relplot(data=df, x="aspect_ratio", y="intensity_mean", size="area")
